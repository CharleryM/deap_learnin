# %%
import seaborn as sns
import os
import matplotlib.pyplot
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

# %%
iris = load_iris()
x = iris.data
y = iris.target

print(f"X shape : {X.shape}")
print(f"Y unique : {np.unique(y)}")
print(f"Features : {iris.feature_name}")
print(f"classes : {iris.target_name}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 iris = load_iris()
#       2 x = iris.data
#       3 y = iris.target
#       4
# ----> 5 print(f"X shape : {X.shape}")
#       6 print(f"Y unique : {np.unique(y)}")
#       7 print(f"Features : {iris.feature_name}")
#       8 print(f"classes : {iris.target_name}")
#
# NameError: name 'X' is not defined
